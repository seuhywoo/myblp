# %%
import pyblp
import pandas as pd

# 제품 데이터
product_data = pd.read_csv(pyblp.data.NEVO_PRODUCTS_LOCATION)
product_data.to_csv('nevo_products.csv', index=False)

# 소비자 데이터 (demographics + draws)
agent_data = pd.read_csv(pyblp.data.NEVO_AGENTS_LOCATION)
agent_data.to_csv('nevo_agents.csv', index=False)

print(product_data.columns.tolist())
print(product_data.shape)   # (2256, ...)
